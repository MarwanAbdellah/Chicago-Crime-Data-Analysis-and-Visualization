# %% [markdown]
# # Folium Data Analysis and Visualization Exercise
#
#
# **Dataset**: You will be using the [Chicago Crime Dataset (2001 - Present)](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2).
#
# **Objectives**:
# 1. Load and inspect the dataset.
# 2. Set up a map and add crime markers based on different crime types.
# 3. Marker clusters to visualize high-density crime areas.
# 4. Create toggle layers for specific types of crimes.

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import folium

# %% [markdown]
# ### Importing the dataset we will use to get the criminal records

# %%
url = "https://data.cityofchicago.org/resource/crimes.csv"

df_incidents = pd.read_csv(url)

df_incidents.head()

# %% [markdown]
# #### It is a big data set as I will show so will only use a small part of it to visuzalize it more accurately

# %%
df_incidents.shape
# Out:
# (1000, 22)

# %%
df_incidents.isnull().sum()
# Out:
# id                       0
# case_number              0
# date                     0
# block                    0
# iucr                     0
# primary_type             0
# description              0
# location_description     3
# arrest                   0
# domestic                 0
# beat                     0
# district                 0
# ward                     0
# community_area           0
# fbi_code                 0
# x_coordinate            14
# y_coordinate            14
# year                     0
# updated_on               0
# latitude                14
# longitude               14
# location                14
# dtype: int64

# %%
df_incidents.dropna(inplace=True)
df_incidents.isnull().sum()
# Out:
# id                      0
# case_number             0
# date                    0
# block                   0
# iucr                    0
# primary_type            0
# description             0
# location_description    0
# arrest                  0
# domestic                0
# beat                    0
# district                0
# ward                    0
# community_area          0
# fbi_code                0
# x_coordinate            0
# y_coordinate            0
# year                    0
# updated_on              0
# latitude                0
# longitude               0
# location                0
# dtype: int64

# %%
df_incidents = df_incidents.head(200)
print("Successful! you have selected the first 200 rows of the dataset")
# Out:
# Successful! you have selected the first 200 rows of the dataset

# %% [markdown]
# ### Setting up the map and adding the crime markers based on different crime types

# %% [markdown]
# #### Setting up the map focusing on Chicago

# %%
chicago_map = folium.Map(location=[41.881832,-87.623177], zoom_start= 10)
chicago_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8b3bdb0919f8696d77ce7aaaab95747 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8b3bdb0919f8696d77ce7aaaab95747&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8b3bdb0919f8696d77ce7aaaab95747 = L.map(
#                 &quot;map_a8b3bdb0919f8696d77ce7aaaab95747&quot;,
#                 {
#                     center: [41.881832, -87.623177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_19a7b7d5fc80ff48068e2afaad7d01d2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_19a7b7d5fc80ff48068e2afaad7d01d2.addTo(map_a8b3bdb0919f8696d77ce7aaaab95747);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### The function that adds markers to the map

# %%
df_incidents['primary_type'].unique()
# Out:
# array(['CRIMINAL DAMAGE', 'ASSAULT', 'THEFT', 'BURGLARY', 'ROBBERY',
#        'DECEPTIVE PRACTICE', 'WEAPONS VIOLATION', 'BATTERY',
#        'OTHER OFFENSE', 'NARCOTICS', 'PUBLIC PEACE VIOLATION',
#        'MOTOR VEHICLE THEFT', 'SEX OFFENSE', 'CRIMINAL TRESPASS',
#        'PROSTITUTION', 'INTERFERENCE WITH PUBLIC OFFICER',
#        'LIQUOR LAW VIOLATION'], dtype=object)

# %% [markdown]
# #### Defining each crime and assigning a color to each of them

# %%
# Define colors for each crime category
crime_colors = {
    'CRIMINAL DAMAGE': 'red',
    'ASSAULT': 'orange',
    'DECEPTIVE PRACTICE': 'blue',
    'ROBBERY': 'green',
    'THEFT': 'purple',
    'BURGLARY': 'brown',
    'WEAPONS VIOLATION': 'black',
    'BATTERY': 'yellow',
    'OTHER OFFENSE': 'gray',
    'NARCOTICS': 'pink',
    'PUBLIC PEACE VIOLATION': 'cyan',
    'MOTOR VEHICLE THEFT': 'darkblue',
    'SEX OFFENSE': 'violet',
    'CRIMINAL TRESPASS': 'lightgreen',
    'PROSTITUTION': 'darkred',
    'INTERFERENCE WITH PUBLIC OFFICER': 'lightblue',
    'LIQUOR LAW VIOLATION': 'gold',
    'OFFENSE INVOLVING CHILDREN': 'lightpink',
    'ARSON': 'firebrick',
    'STALKING': 'darkviolet',
    'CRIMINAL SEXUAL ASSAULT': 'darkgreen'
}

# %% [markdown]
# #### For loop to add markers and changing it's color to match each crime

# %%
incidents = folium.FeatureGroup()

# Adding CircleMarkers with specific colors for each crime
for lat, lng, category in zip(df_incidents.latitude, df_incidents.longitude, df_incidents.primary_type):
    color = crime_colors.get(category, 'black')  # If the crime in our selection wasn't found return to 'black'
    incidents.add_child(folium.features.CircleMarker(
        [lat, lng],
        radius=10,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.6,
        icon = None,
    ))

# Add markers with popup labels for crime categories
for lat, lng, label, category in zip(df_incidents.latitude, df_incidents.longitude, df_incidents.primary_type, df_incidents.primary_type):
    color = crime_colors.get(category, 'black')
    folium.Marker(
        [lat, lng],
        popup=label,
        icon=folium.Icon(color=color, icon_color='white', icon='exclamation-circle', prefix='fa') 
    ).add_to(chicago_map)

# Add the incidents feature group to the map
chicago_map.add_child(incidents)
# Out:
# C:\Users\maraw\AppData\Local\Temp\ipykernel_183040\794583060.py:22: UserWarning: color argument of Icon should be one of: {'cadetblue', 'gray', 'black', 'orange', 'darkred', 'white', 'beige', 'lightgray', 'darkpurple', 'green', 'darkblue', 'lightblue', 'red', 'darkgreen', 'purple', 'lightred', 'lightgreen', 'blue', 'pink'}.
#   icon=folium.Icon(color=color, icon_color='white', icon='exclamation-circle', prefix='fa')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8b3bdb0919f8696d77ce7aaaab95747 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8b3bdb0919f8696d77ce7aaaab95747&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8b3bdb0919f8696d77ce7aaaab95747 = L.map(
#                 &quot;map_a8b3bdb0919f8696d77ce7aaaab95747&quot;,
#                 {
#                     center: [41.881832, -87.623177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_19a7b7d5fc80ff48068e2afaad7d01d2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_19a7b7d5fc80ff48068e2afaad7d01d2.addTo(map_a8b3bdb0919f8696d77ce7aaaab95747);
#
#
#             tile_layer_19a7b7d5fc80ff48068e2afaad7d01d2.addTo(map_a8b3bdb0919f8696d77ce7aaaab95747);
#
#
#             var marker_7b24e30daeacd3d926cf91f940e61d7a = L.marker(
#                 [41.888651894, -87.74976443],
#                 {}
#             ).addTo(map_a8b3bdb0919f8696d77ce7aaaab95747);
#
#
#             var icon_7f99e3af8058f56df3982628765eeacd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;exclamation-circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7b24e30daeacd3d926cf91f940e61d7a.setIcon(icon_7f99e3af8058f56df3982628765eeacd);
#
#
#         var popup_a21831557e667602c5eccc4a0286c56b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5f56fc84f85fbe846077be792cf699cb = $(`&lt;div id=&quot;html_5f56fc84f85fbe846077be792cf699cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CRIMINAL DAMAGE&lt;/div&gt;`)[0];
#                 popup_a21831557e667602c5eccc4a0286c56b.setContent(html_5f56fc84f85fbe846077be792cf699cb);
#
#
#
#         marker_7b24e30daeacd3d926cf91f940e61d7a.bindPopup(popup_a21831557e667602c5eccc4a0286c56b)
#         ;
#
#
#
#
#             var marker_28a76b16248182e9f549f09b2ada1c7d = L.marker(
#                 [41.885026163, -87.67552729],
#                 {}
#             ).addTo(map_a8b3bdb0919f8696d77ce7aaaab95747);
#
#
#             var icon_43d4196c4280cf5aefc54017989e4e2e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;exclamation-circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_28a76b16248182e9f549f09b2ada1c7d.setIcon(icon_43d4196c4280cf5aefc54017989e4e2e);
#
#
#         var popup_2b3d8b7cc418276f10a33d1f0b16f7ca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6442676b60c6dfbbad50b6ed7981856c = $(`&lt;div id=&quot;html_6442676b60c6dfbbad50b6ed7981856c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ASSAULT&lt;/div&gt;`)[0];
#                 popup_2b3d8b7cc418276f10a33d1f0b16f7ca.setContent(html_6442676b60c6dfbbad50b6ed7981856c);
#
#
#
#         marker_28a76b16248182e9f549f09b2ada1c7d.bindPopup(popup_2b3d8b7cc418276f10a33d1f0b16f7ca)
#         ;
#
#
#
#
#             var marker_840e35d501874543b13c3a063e128294 = L.marker(
#                 [41.679043182, -87.684851671],
#                 {}
#             ).addTo(map_a8b3bdb0919f8696d77ce7aaaab95747);
#
#
#             var icon_e013fa4d8c2546935a0f552689ac8a70 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;exclamation-circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_840e35d501874543b13c3a063e128294.setIcon(icon_e013fa4d8c2546935a0f552689ac8a70);
#
#
#         var popup_564f2840d390f0368b54d80ca35fcbe3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f5074399bbc5af23fb3af62d753618be = $(`&lt;div id=&quot;html_f5074399bbc5af23fb3af62d753618be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;THEFT&lt;/div&gt;`)[0];
#                 popup_564f2840d390f0368b54d80ca35fcbe3.setContent(html_f5074399bbc5af23fb3af62d753618be);
#
#
#
#         marker_840e35d501874543b13c3a063e128294.bindPopup(popup_564f2840d390f0368b54d80ca35fcbe3)
#         ;
#
#
#
#
#             var marker_0419879d4378fa15b479e758c3f7b440 = L.marker(
#                 [41.745050505, -87.613545923],
#                 {}
#             ).addTo(map_a8b3bdb0919f8696d77ce7aaaab95747);
#
#
#             var icon_286fb74659029fd1f82d5ea5d0957e2c = L.AwesomeMarkers.icon(

# %% [markdown]
# ### Using the Clustering method

# %% [markdown]
# #### Creating a new map to get rid of the markers

# %%
chicago_map = folium.Map(location=[41.881832,-87.623177], zoom_start= 10)

# %% [markdown]
# #### Adding the clusters to show the density of the criminal records in each area

# %%
from folium import plugins
incidents = plugins.MarkerCluster().add_to(chicago_map)

labels = list(df_incidents.primary_type)

for lat, lng, label in zip(df_incidents.latitude, df_incidents.longitude, labels):
    folium.Marker(
        location = [lat, lng],
        icon = folium.Icon(color='blue', icon='exclamation-circle', prefix='fa'),
        popup = label
    ).add_to(incidents)
    
chicago_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3117898e82ab4f67e6c95e51549e09c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3117898e82ab4f67e6c95e51549e09c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3117898e82ab4f67e6c95e51549e09c9 = L.map(
#                 &quot;map_3117898e82ab4f67e6c95e51549e09c9&quot;,
#                 {
#                     center: [41.881832, -87.623177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a82cdbb0c3d02d1091e7a56da0a05057 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a82cdbb0c3d02d1091e7a56da0a05057.addTo(map_3117898e82ab4f67e6c95e51549e09c9);
#
#
#             var marker_cluster_ad30d760adbd9e704a7d956e64b35a6b = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_6d603b6ea400cf64ec55a9c7e3faa795 = L.marker(
#                 [41.888651894, -87.74976443],
#                 {}
#             ).addTo(marker_cluster_ad30d760adbd9e704a7d956e64b35a6b);
#
#
#             var icon_d763d51ebc79d01d37e9efd00d2e1c9a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;exclamation-circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6d603b6ea400cf64ec55a9c7e3faa795.setIcon(icon_d763d51ebc79d01d37e9efd00d2e1c9a);
#
#
#         var popup_1ff887911fd64f231f2fdb791d1b1333 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_52f499fe78fd1f1cb168dc8f9950b1bb = $(`&lt;div id=&quot;html_52f499fe78fd1f1cb168dc8f9950b1bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CRIMINAL DAMAGE&lt;/div&gt;`)[0];
#                 popup_1ff887911fd64f231f2fdb791d1b1333.setContent(html_52f499fe78fd1f1cb168dc8f9950b1bb);
#
#
#
#         marker_6d603b6ea400cf64ec55a9c7e3faa795.bindPopup(popup_1ff887911fd64f231f2fdb791d1b1333)
#         ;
#
#
#
#
#             var marker_f341949094537e935fbcc4b7cee31aa7 = L.marker(
#                 [41.885026163, -87.67552729],
#                 {}
#             ).addTo(marker_cluster_ad30d760adbd9e704a7d956e64b35a6b);
#
#
#             var icon_fe093104ad9942c1b1a5ab26155920dc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;exclamation-circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f341949094537e935fbcc4b7cee31aa7.setIcon(icon_fe093104ad9942c1b1a5ab26155920dc);
#
#
#         var popup_dec252d2c793d38f23a45963bd48b559 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e2702a868b7576111967c9ab0a3ae55 = $(`&lt;div id=&quot;html_8e2702a868b7576111967c9ab0a3ae55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ASSAULT&lt;/div&gt;`)[0];
#                 popup_dec252d2c793d38f23a45963bd48b559.setContent(html_8e2702a868b7576111967c9ab0a3ae55);
#
#
#
#         marker_f341949094537e935fbcc4b7cee31aa7.bindPopup(popup_dec252d2c793d38f23a45963bd48b559)
#         ;
#
#
#
#
#             var marker_c7fea64bd3b3872ba293b66c724979f3 = L.marker(
#                 [41.679043182, -87.684851671],
#                 {}
#             ).addTo(marker_cluster_ad30d760adbd9e704a7d956e64b35a6b);
#
#
#             var icon_89df5d07c3b9d7cf2023f5147e12dba1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;exclamation-circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c7fea64bd3b3872ba293b66c724979f3.setIcon(icon_89df5d07c3b9d7cf2023f5147e12dba1);
#
#
#         var popup_68cb04cc588a1ff758ba984843e83177 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_329683acaea69dfdf9977da4c8f3f5b5 = $(`&lt;div id=&quot;html_329683acaea69dfdf9977da4c8f3f5b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;THEFT&lt;/div&gt;`)[0];
#                 popup_68cb04cc588a1ff758ba984843e83177.setConten

# %% [markdown]
# ### Heatmap for each crime

# %%
chicago_map = folium.Map(location=[41.881832,-87.623177], zoom_start= 10)

# %%
# Extract crime data from our dataset
locations = list(zip(df_incidents['latitude'], df_incidents['longitude'])) 

# Creating a heatmap using the latitudes and longitudes pairs we obtained 
heat_data = [[lat, lng] for lat, lng in locations]  

plugins.HeatMap(heat_data).add_to(chicago_map)

chicago_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5e7549df7af41939d5698ea22471058 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5e7549df7af41939d5698ea22471058&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5e7549df7af41939d5698ea22471058 = L.map(
#                 &quot;map_c5e7549df7af41939d5698ea22471058&quot;,
#                 {
#                     center: [41.881832, -87.623177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d2451e82dc9122ed7ba1dc09f8efe67e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d2451e82dc9122ed7ba1dc09f8efe67e.addTo(map_c5e7549df7af41939d5698ea22471058);
#
#
#             var heat_map_e8172381e5c9be1cf57274b77f27db83 = L.heatLayer(
#                 [[41.888651894, -87.74976443], [41.885026163, -87.67552729], [41.679043182, -87.684851671], [41.745050505, -87.613545923], [41.944825475, -87.779508037], [41.878401489, -87.760539546], [41.684547084, -87.648216209], [41.881650549, -87.632355065], [41.960765516, -87.691790461], [41.910470235, -87.751707591], [41.755204004, -87.652651208], [41.793277384, -87.666997721], [41.953852531, -87.713208208], [41.76159766, -87.610329804], [41.790950765, -87.594826035], [41.996496751, -87.787072648], [41.852868298, -87.63091491], [41.914480584, -87.79525666], [41.87531818, -87.721407092], [41.799223285, -87.624206467], [41.865662714, -87.704424107], [41.657321932, -87.606458295], [41.872332627, -87.679608149], [41.777236833, -87.692534014], [41.908346262, -87.757163971], [41.87405601, -87.746148365], [41.686168566, -87.642187581], [41.959729751, -87.732655928], [41.894112156, -87.721150596], [41.960660544, -87.656307554], [41.808500903, -87.616562762], [41.729194874, -87.567017296], [41.90836547, -87.757163798], [41.966739557, -87.729203503], [41.88428199, -87.662634028], [41.918161236, -87.719858934], [41.808500903, -87.616562762], [41.994913946, -87.881937669], [41.993043969, -87.660360363], [41.837057439, -87.631619928], [41.773341845, -87.585250879], [41.861008942, -87.705515947], [41.764313073, -87.562820451], [41.885655744, -87.648036529], [41.807306046, -87.732137903], [41.936577088, -87.729572792], [41.86692722, -87.715436748], [42.02223302, -87.66727331], [41.862866414, -87.714036773], [41.753204151, -87.73040747], [41.750583277, -87.58945839], [41.832115912, -87.641265568], [41.970787326, -87.661091127], [41.90263398, -87.750878734], [42.018498254, -87.672983233], [41.751259643, -87.562588118], [41.772615878, -87.700535132], [41.938015811, -87.745584039], [41.829858435, -87.665550742], [41.772553923, -87.60701374], [41.783238071, -87.618930466], [41.751898652, -87.650135449], [41.971265482, -87.778267791], [41.694936031, -87.623170914], [41.774472734, -87.633633309], [41.870831162, -87.716247283], [41.735525546, -87.619349553], [41.872910562, -87.63062942], [41.719557069, -87.534806503], [41.911170142, -87.631881548], [41.799168269, -87.739867984], [41.694232498, -87.620795021], [41.799808989, -87.723350952], [41.877480792, -87.692256931], [41.885481891, -87.627935689], [41.919855859, -87.731538235], [41.909240284, -87.65274758], [41.959891679, -87.767222504], [41.678619903, -87.669832762], [41.736604359, -87.608005164], [41.791666859, -87.632921961], [41.978160468, -87.689240087], [41.748912644, -87.566185508], [41.749064315, -87.599058871], [41.731427876, -87.653210024], [41.892727253, -87.65583178], [41.876076856, -87.686583248], [41.7030247, -87.620694297], [41.884809541, -87.763343087], [41.868761025, -87.627458687], [41.885113405, -87.673036523], [41.925805079, -87.805097956], [41.968167905, -87.734702055], [41.829061437, -87.614440155], [41.922957503, -87.743833539], [41.899740053, -87.665418211], [41.909302028, -87.684752756], [41.891408158, -87.641253937], [41.93791173, -87.727149134], [41.93030588, -87.709430607], [41.894385607, -87.719939597], [41.867884137, -87.624101672], [41.825035599, -87.605723772], [41.695332831, -87.620771891], [41.763647371, -87.586265199], [41.767114832, -87.571023597], [41.741113895, -87.619500171], [41.750843608, -87.603952966], [41.895732399, -87.687784384], [41.740878678, -87.622727222], [41.886202772, -87.620685715], [41.873668176, -87.686233016], [41.880255584, -87.627728782], [41.874225203, -87.735854874], [41.740715225, -87.669263548], [41.967929496, -87.649288171], [41.764151886, -87.683229302], [41.767114832, -87.571023597], [41.816518342, -87.689552652], [41.903458863, -87.758276883], [41.8918977, -87.773336129], [41.853900567, -87.623841404], [41.781571551, -87.711783801], [41.891105848, -87.764098787], [41.961635711, -87.777064504], [41.856057106, -87.723631656], [41.722927697, -87.612961

# %% [markdown]
# ## Bonus:  Adding toggle layers to filter each crime and only display the selected one

# %%
chicago_map = folium.Map(location=[41.881832,-87.623177], zoom_start= 10)

# %% [markdown]
# #### The map is set to be empty in the beginning with the layers legend on the top right to choose the specific crime you want to see

# %%
# Creating a crime category for each crime category
crime_categories = {}

# Looping through the crime_colors dictionary to create crime categories
for category, color in crime_colors.items():
    crime_category = folium.FeatureGroup(name=category, show=False)  # Creating a new crime category for each category # Show = False to start with the map being empty
    
    # Filtering the dataset for each crime category
    category_data = df_incidents[df_incidents['primary_type'] == category]
    
    # Adding CircleMarkers for each crime
    for lat, lng in zip(category_data.latitude, category_data.longitude):
        folium.features.CircleMarker(
            [lat, lng],
            radius=10,
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=0.6,
            popup=category  
        ).add_to(crime_category)  # Adding CircleMarker to the corresponding crime category

    # Adding the crime category to the map after it's populated with CircleMarkers
    crime_categories[category] = crime_category

# Adding all crime categories to the map
for category in crime_categories.values():
    category.add_to(chicago_map)

# Adding LayerControl to allow toggling crime categories
folium.LayerControl().add_to(chicago_map)

# Showing the map
chicago_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff6214bd9d23f1639c938db076e55f53 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff6214bd9d23f1639c938db076e55f53&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff6214bd9d23f1639c938db076e55f53 = L.map(
#                 &quot;map_ff6214bd9d23f1639c938db076e55f53&quot;,
#                 {
#                     center: [41.881832, -87.623177],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72e5022ac85994f5c187918961bc2a03 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_72e5022ac85994f5c187918961bc2a03.addTo(map_ff6214bd9d23f1639c938db076e55f53);
#
#
#             var feature_group_63b2b31629ea8fdb44f99b4a3bdd5ba7 = L.featureGroup(
#                 {}
#             );
#
#
#             var circle_marker_57f12379ed6d7712747fee7ae9a3fa53 = L.circleMarker(
#                 [41.888651894, -87.74976443],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_63b2b31629ea8fdb44f99b4a3bdd5ba7);
#
#
#         var popup_534568dee2a8a7eee90007703b086c34 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_93512bac6915ea5d18da5739cc2e9285 = $(`&lt;div id=&quot;html_93512bac6915ea5d18da5739cc2e9285&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CRIMINAL DAMAGE&lt;/div&gt;`)[0];
#                 popup_534568dee2a8a7eee90007703b086c34.setContent(html_93512bac6915ea5d18da5739cc2e9285);
#
#
#
#         circle_marker_57f12379ed6d7712747fee7ae9a3fa53.bindPopup(popup_534568dee2a8a7eee90007703b086c34)
#         ;
#
#
#
#
#             var circle_marker_339e88606c463890fb2e90b6641795f9 = L.circleMarker(
#                 [41.944825475, -87.779508037],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_63b2b31629ea8fdb44f99b4a3bdd5ba7);
#
#
#         var popup_a618c30b72aa3ade3c1301ba25f3f6c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ce0a6eb67f3f9086c21eee7ce35023ea = $(`&lt;div id=&quot;html_ce0a6eb67f3f9086c21eee7ce35023ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CRIMINAL DAMAGE&lt;/div&gt;`)[0];
#                 popup_a618c30b72aa3ade3c1301ba25f3f6c7.setContent(html_ce0a6eb67f3f9086c21eee7ce35023ea);
#
#
#
#         circle_marker_339e88606c463890fb2e90b6641795f9.bindPopup(popup_a618c30b72aa3ade3c1301ba25f3f6c7)
#         ;
#
#
#
#
#             var circle_marker_9e13f2727779a06cb2f415331b1891be = L.circleMarker(
#                 [41.793277384, -87.666997721],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_63b2b31629ea8fdb44f99b4a3bdd5ba7);
#
#
#         var popup_f76cf78a65921fd057fca17244e61cf3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_60441724bd9032b1e40490b02978c41b = $(`&lt;div id=&quot;html_60441724bd9032b1e40490b02978c41b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CRIMINAL DAMAGE&lt;/div&gt;`)[0];
#                 popup_f76cf78a65921fd057fca17244e61cf3.setContent(html_60441724bd9032b1e40490b02978c41b);
#
#
#
#         circle_marker_9e13f2727779a06cb2f415331b1891be.bindPopup(popup_f76cf78a65921fd057fca17244e61cf3)
#         ;
#
#
#
#
#             var circle_marker_92d642628022399789d295d13e8048e7 = L.circleMarker(
#                 [41.908346262, -87.757163971],
#                 {&quot;bubblingMouseEvents&quot;
